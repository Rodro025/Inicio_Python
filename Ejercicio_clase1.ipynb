# %% [markdown]
# <a href="https://colab.research.google.com/github/Rodro025/Inicio_Python/blob/main/Ejercicio_clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hacer un primer grafico con matplotlib y seaborn
# [Este es un link adicional:]https://git-scm.com/book/es/v2/Inicio---Sobre-el-Control-de-Versiones-Configurando-Git-por-primera-vez

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=['EDA','Data Wrangling','Mineria datos','Limpieza Datos','SQL','Est. Inferencial','ML','DL','IA']
y= [5,10,15,20,30,25,31,30,20]

data = {
    "Conocimientos Previos":x,
    "Frecuencia": y
}

dataset = pd.DataFrame(data)
dataset

# Visualizar los datos
plt.figure(figsize=(16, 9))
sns.set_style("darkgrid")
ax = sns.barplot(x="Conocimientos Previos", y="Frecuencia",data=dataset)
plt.title('Importancia de habilidades en data science', fontsize=16)
plt.xlabel('Habilidad', fontsize=12)
plt.ylabel('Nivel de importancia', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Añadir etiquetas de valor en cada barra
for i, v in enumerate(dataset['Frecuencia']):
  ax.text(i, v + 0.5, str(v), ha='center', fontsize=10)

  plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-834b04f05916> in <cell line: 0>()
#       2 plt.figure(figsize=(16, 9))
#       3 sns.set_style("darkgrid")
# ----> 4 ax = sns.barplot(x="Conoocimientos Previos", y="Frecuencia",data=dataset)
#       5 plt.title('Importancia de habilidades en data science', fontsize=16)
#       6 plt.xlabel('Habilidad', fontsize=12)
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2339         estimator = "size"
#    2340
# -> 2341     p = _CategoricalAggPlotter(
#    2342         data=data,
# ...
